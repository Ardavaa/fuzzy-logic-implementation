# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/kb22/Heart-Disease-Prediction/refs/heads/master/dataset.csv')
data2 = data[['age', 'trestbps', 'chol', 'target']]

data2['ID'] = np.arange(111, 414, 1)
data2
# Out:
# C:\Users\ardav\AppData\Local\Temp\ipykernel_17304\4024879099.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['ID'] = np.arange(111, 414, 1)
#      age  trestbps  chol  target   ID
# 0     63       145   233       1  111
# 1     37       130   250       1  112
# 2     41       130   204       1  113
# 3     56       120   236       1  114
# 4     57       120   354       1  115
# ..   ...       ...   ...     ...  ...
# 298   57       140   241       0  409
# 299   45       110   264       0  410
# 300   68       144   193       0  411
# 301   57       130   131       0  412
# 302   57       130   236       0  413
#
# [303 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fuzzy membership functions for Age
age_young = [[50, 0], [30, 1], [0, 1]]   # Muda (Young)
age_adult = [[70, 0], [50, 1], [30, 0]]  # Dewasa (Adult) - changed to triangle
age_old = [[100, 1], [70, 1], [50, 0]]   # Tua (Old)

# List of fuzzy sets for Age
age_sets = [age_young, age_adult, age_old]

# Create plot for Age
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each fuzzy set for Age
for age in age_sets:
    xs, ys = zip(*age)
    ax.plot(xs, ys)

# Labels and title for Age plot
plt.xlabel("Nilai Kelayakan")
plt.ylabel("Keanggotaan")
plt.title("Skala Nilai Kelayakan untuk Usia (Age)")

# Add legend
plt.legend(["Muda (Young)", "Dewasa (Adult)", "Tua (Old)"])

# Show grid and plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fuzzy membership functions for Blood Pressure (Trestbps)
bp_low = [[130, 0], [90, 1], [0, 1]]  # Rendah (Low)
bp_normal = [[170, 0], [130, 1], [90, 0]]  # Normal (segitiga)
bp_high = [[200, 1], [170, 1], [130, 0]]  # Tinggi (High)

# List of fuzzy sets for Blood Pressure
bp_sets = [bp_low, bp_normal, bp_high]

# Create plot for Blood Pressure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each fuzzy set for Blood Pressure
for bp in bp_sets:
    xs, ys = zip(*bp)
    ax.plot(xs, ys)

# Labels and title for Blood Pressure plot
plt.xlabel("Nilai Kelayakan")
plt.ylabel("Keanggotaan")
plt.title("Skala Nilai Kelayakan untuk Tekanan Darah (Blood Pressure)")

# Add legend
plt.legend(["Rendah (Low BP)", "Normal (Normal BP)", "Tinggi (High BP)"])

# Show grid and plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fuzzy membership functions for Cholesterol (Chol)
chol_low = [[200, 0], [150, 1], [0, 1]]  # Rendah (Low)
chol_medium = [[240, 0], [200, 1], [150, 0]]  # Sedang (Medium) - segitiga
chol_high = [[300, 1], [240, 1], [200, 0]]  # Tinggi (High)

# List of fuzzy sets for Cholesterol
chol_sets = [chol_low, chol_medium, chol_high]

# Create plot for Cholesterol
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each fuzzy set for Cholesterol
for chol in chol_sets:
    xs, ys = zip(*chol)
    ax.plot(xs, ys)

# Labels and title for Cholesterol plot
plt.xlabel("Nilai Kelayakan")
plt.ylabel("Keanggotaan")
plt.title("Skala Nilai Kelayakan untuk Kolesterol (Cholesterol)")

# Add legend
plt.legend(["Rendah (Low Chol)", "Sedang (Medium Chol)", "Tinggi (High Chol)"])

# Show grid and plot
plt.grid(True)
plt.show()

# %%
from tabulate import tabulate

# Data kombinasi Usia dan Tekanan Darah
data = [
    ['Muda', 'Rendah', 'Sedang', 'Tinggi'],
    ['Muda', 'Normal', 'Sedang', 'Tinggi'],
    ['Muda', 'Tinggi', 'Tinggi', 'Tinggi'],
    ['Dewasa', 'Rendah', 'Sedang', 'Tinggi'],
    ['Dewasa', 'Normal', 'Normal', 'Tinggi'],
    ['Dewasa', 'Tinggi', 'Tinggi', 'Tinggi'],
    ['Tua', 'Rendah', 'Tinggi', 'Tinggi'],
    ['Tua', 'Normal', 'Tinggi', 'Tinggi'],
    ['Tua', 'Tinggi', 'Tinggi', 'Tinggi']
]

# Headers for the table
headers = ['Usia\\Tekanan Darah', 'Rendah', 'Normal', 'Tinggi']

# Display the table
print(tabulate(data, headers, tablefmt='grid'))
# Out:
# +----------------------+----------+----------+----------+
# | Usia\Tekanan Darah   | Rendah   | Normal   | Tinggi   |
# +======================+==========+==========+==========+
# | Muda                 | Rendah   | Sedang   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Muda                 | Normal   | Sedang   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Muda                 | Tinggi   | Tinggi   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Dewasa               | Rendah   | Sedang   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Dewasa               | Normal   | Normal   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Dewasa               | Tinggi   | Tinggi   | Tinggi   |
# +----------------------+----------+----------+----------+
# | Tua                  | Rendah   | Tinggi   | Tinggi   |
# ...

# %%
from tabulate import tabulate

# Data kombinasi Usia dan Kolesterol
data = [
    ['Muda', 'Rendah', 'Sedang', 'Tinggi'],
    ['Muda', 'Sedang', 'Sedang', 'Tinggi'],
    ['Muda', 'Tinggi', 'Tinggi', 'Tinggi'],
    ['Dewasa', 'Rendah', 'Sedang', 'Tinggi'],
    ['Dewasa', 'Sedang', 'Normal', 'Tinggi'],
    ['Dewasa', 'Tinggi', 'Tinggi', 'Tinggi'],
    ['Tua', 'Rendah', 'Tinggi', 'Tinggi'],
    ['Tua', 'Sedang', 'Tinggi', 'Tinggi'],
    ['Tua', 'Tinggi', 'Tinggi', 'Tinggi']
]

# Headers for the table
headers = ['Usia\\Kolesterol', 'Rendah', 'Sedang', 'Tinggi']

# Display the table
print(tabulate(data, headers, tablefmt='grid'))
# Out:
# +-------------------+----------+----------+----------+
# | Usia\Kolesterol   | Rendah   | Sedang   | Tinggi   |
# +===================+==========+==========+==========+
# | Muda              | Rendah   | Sedang   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Muda              | Sedang   | Sedang   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Muda              | Tinggi   | Tinggi   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Dewasa            | Rendah   | Sedang   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Dewasa            | Sedang   | Normal   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Dewasa            | Tinggi   | Tinggi   | Tinggi   |
# +-------------------+----------+----------+----------+
# | Tua               | Rendah   | Tinggi   | Tinggi   |
# +-------------------+----------+----------+----------+
# ...

# %%
from tabulate import tabulate

# Data kombinasi Tekanan Darah dan Kolesterol
data = [
    ['Rendah', 'Rendah', 'Sedang', 'Tinggi'],
    ['Normal', 'Sedang', 'Normal', 'Tinggi'],
    ['Tinggi', 'Tinggi', 'Tinggi', 'Tinggi'],
]

# Headers for the table
headers = ['Tekanan Darah\\Kolesterol', 'Rendah', 'Sedang', 'Tinggi']

# Display the table
print(tabulate(data, headers, tablefmt='grid'))
# Out:
# +----------------------------+----------+----------+----------+
# | Tekanan Darah\Kolesterol   | Rendah   | Sedang   | Tinggi   |
# +============================+==========+==========+==========+
# | Rendah                     | Rendah   | Sedang   | Tinggi   |
# +----------------------------+----------+----------+----------+
# | Normal                     | Sedang   | Normal   | Tinggi   |
# +----------------------------+----------+----------+----------+
# | Tinggi                     | Tinggi   | Tinggi   | Tinggi   |
# +----------------------------+----------+----------+----------+

# %%
import pandas as pd
import numpy as np

# Fungsi Keanggotaan untuk Tekanan Darah (trestbps)
def fuzzification_trestbps(x):
    if x < 90:
        return [1, 0, 0]  # Rendah: 1, Normal: 0, Tinggi: 0
    elif 90 <= x <= 130:
        return [(130 - x) / 40, (x - 90) / 40, 0]  # Menurun dari rendah ke normal
    elif 130 < x <= 170:
        return [0, (170 - x) / 40, (x - 130) / 40]  # Menurun dari normal ke tinggi
    else:
        return [0, 0, 1]  # Tinggi: 1

# Fungsi Keanggotaan untuk Kolesterol (chol)
def fuzzification_chol(x):
    if x < 200:
        return [1, 0, 0]  # Rendah: 1, Sedang: 0, Tinggi: 0
    elif 200 <= x <= 240:
        return [(240 - x) / 40, (x - 200) / 40, 0]  # Menurun dari rendah ke sedang
    elif 240 < x <= 280:
        return [0, (280 - x) / 40, (x - 240) / 40]  # Menurun dari sedang ke tinggi
    else:
        return [0, 0, 1]  # Tinggi: 1

# Fungsi Keanggotaan untuk Usia (age)
def fuzzification_age(x):
    if x < 30:
        return [1, 0, 0]  # Muda: 1, Dewasa: 0, Tua: 0
    elif 30 <= x <= 50:
        return [(50 - x) / 20, (x - 30) / 20, 0]  # Menurun dari muda ke dewasa
    elif 50 < x <= 70:
        return [0, (70 - x) / 20, (x - 50) / 20]  # Menurun dari dewasa ke tua
    else:
        return [0, 0, 1]  # Tua: 1

# %%
# Fungsi Inferensi Mamdani
def inferensi_mamdani(trestbps_fuzz, chol_fuzz, age_fuzz):
    # 27 aturan untuk kombinasi keanggotaan
    aturan = []

    # Kombinasi untuk Rendah pada trestbps, Rendah pada chol, Muda pada age
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[0]))  # Rendah - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[1]))  # Rendah - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[2]))  # Rendah - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Rendah pada trestbps, Rendah pada chol, Dewasa pada age
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[0]))  # Rendah - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[1]))  # Rendah - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[2]))  # Rendah - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Rendah pada trestbps, Rendah pada chol, Tua pada age
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[0]))  # Rendah - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[1]))  # Rendah - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[0], chol_fuzz[0], age_fuzz[2]))  # Rendah - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Normal pada trestbps, Rendah pada chol, Muda pada age
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[0]))  # Normal - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[1]))  # Normal - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[2]))  # Normal - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Normal pada trestbps, Rendah pada chol, Dewasa pada age
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[0]))  # Normal - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[1]))  # Normal - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[2]))  # Normal - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Normal pada trestbps, Rendah pada chol, Tua pada age
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[0]))  # Normal - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[1]))  # Normal - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[1], chol_fuzz[0], age_fuzz[2]))  # Normal - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Tinggi pada trestbps, Rendah pada chol, Muda pada age
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[0]))  # Tinggi - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[1]))  # Tinggi - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[2]))  # Tinggi - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Tinggi pada trestbps, Rendah pada chol, Dewasa pada age
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[0]))  # Tinggi - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[1]))  # Tinggi - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[2]))  # Tinggi - Rendah - Tua -> Output: Tinggi

    # Kombinasi untuk Tinggi pada trestbps, Rendah pada chol, Tua pada age
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[0]))  # Tinggi - Rendah - Muda -> Output: Rendah
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[1]))  # Tinggi - Rendah - Dewasa -> Output: Sedang
    aturan.append(min(trestbps_fuzz[2], chol_fuzz[0], age_fuzz[2]))  # Tinggi - Rendah - Tua -> Output: Tinggi

    return aturan

# Defuzzification menggunakan metode Centroid
def defuzzification(aturan):
    return sum(aturan) / len(aturan) if len(aturan) != 0 else 0

# Proses untuk Fuzzification, Inferensi, dan Defuzzification
id = range(100)  # Misalnya, data ID
trestbps = np.random.randint(80, 180, size=100)  # Data tekanan darah (random)
chol = np.random.randint(150, 300, size=100)  # Data kolesterol (random)
age = np.random.randint(20, 80, size=100)  # Data usia (random)

y = []

for x in range(len(trestbps)):
    # Fuzzifikasi untuk 'trestbps', 'chol', dan 'age'
    trestbps_fuzz = fuzzification_trestbps(trestbps[x])
    chol_fuzz = fuzzification_chol(chol[x])
    age_fuzz = fuzzification_age(age[x])
    
    # Inferensi Mamdani untuk menghasilkan aturan
    aturan = inferensi_mamdani(trestbps_fuzz, chol_fuzz, age_fuzz)
    
    # Defuzzifikasi untuk menghasilkan nilai kelayakan
    kelayakan = defuzzification(aturan)
    
    # Menyimpan hasil untuk evaluasi
    y.append(kelayakan)

# Menampilkan hasil evaluasi
df = pd.DataFrame({
    'ID': id,
    'Trestbps': trestbps,
    'Chol': chol,
    'Age': age,
    'Kelayakan': y
})

print(df.head())
# Out:
#    ID  Trestbps  Chol  Age  Kelayakan
# 0   0       114   178   21   0.111111
# 1   1       114   155   74   0.111111
# 2   2       167   243   59   0.000000
# 3   3       151   161   53   0.144444
# 4   4       111   186   46   0.155556

# %%
df.sort_values(by='Kelayakan', ascending=False).head()
# Out:
#     ID  Trestbps  Chol  Age  Kelayakan
# 83  83       156   189   63   0.188889
# 93  93       107   193   63   0.188889
# 0    0       150   176   56   0.177778
# 29  29       113   196   44   0.177778
# 92  92       109   192   36   0.177778
